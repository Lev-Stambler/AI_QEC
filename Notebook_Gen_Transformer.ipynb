# %%
# !pip install livelossplot -q
# !pip install bposd -q
# !pip install json -q
# !pip install multiprocessing -q

# %%
# !cat results.json || echo '{}' >> results.json
# Out:
# cat: results.json: No such file or directory

# %%
from livelossplot import PlotLosses
from livelossplot.outputs import matplotlib_subplots

# %%
import os
import sys
sys.path.append(os.getcwd() + "/src")

# %%
from training_qec import main
loss_plt = PlotLosses() 
model = main(loss_plt, load_saved_scoring_model=True,
             skip_initialization_training=True, skip_eval=True, initialize_epoch_start=1, genetic_epoch_start=1)
# Out:
# Predicated
# 	Predicated       	 (min:    0.936, max:    0.984, cur:    0.967)
# Real Success Rate
# 	Real Success Rate 	 (min:    0.878, max:    0.990, cur:    0.961)
# Train Delta Err
# 	Train Delta Err  	 (min:    0.000, max:    0.100, cur:    0.006)
# Train Loss
# 	Train Loss       	 (min:    0.000, max:    0.010, cur:    0.000)
# Train std dev
# 	Train std dev    	 (min:    0.000, max:    0.012, cur:    0.010)

# %%
# import code_evaluation
# import numpy as np
# from global_params import params

# e = np.ones(((params['n_data_qubits'] + params['n_check_qubits']) * 2)) * 0.01
# code_evaluation.main(e)
# Out:
# 15262/20000: 0.7631
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
